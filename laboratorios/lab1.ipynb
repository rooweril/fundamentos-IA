# %%
##laboratorio 1
 #1/9/26
 #fabrizzio

# %%
print ('mi primer sistema inteligente')
nombre = input('escriba su nombre empezando por apellido paterno')
matricula = input('ingrese su matricula')
promedio = float (input('escribe tu calificacion'))
# Out:
# mi primer sistema inteligente
# escriba su nombre empezando por apellido paterno narvaez franco fabrizzio
# ingrese su matricula 20243l601015
# escribe tu calificacion 10

# %%
print ('datos almacenados')
print ('nombre: ', nombre)
print ('matricula: ', matricula)
print ('promedio: ', promedio)
# Out:
# datos almacenados
# nombre:  narvaez franco fabrizzio
# matricula:  20243l601015
# promedio:  10.0

# %%
#reglas
if (promedio >=8 and promedio <= 10):
    print ('exelente')
elif (promedio < 8 and promedio >=7):
    print ('mejora')
elif (promedio <7 and promedio >=6):
    print ('necesitas ayuda')
else:
    print ('date de baja')
# Out:
# exelente
