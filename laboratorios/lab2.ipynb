# %%
### laboratorio 2
  # 1/9/26
  # fabrizzio
  # problema de realizar un sistema que identifique si una planta necesita riego para activar el sensor

# %%
print ('sistema inteligente de riego de planta')
temperatura = float(input ('introduzca la temperatura detectada'))
planta = input ('introduzca el nombre de la planta')
# Out:
# sistema inteligente de riego de planta
# introduzca la temperatura detectada 60
# introduzca el nombre de la planta fa

# %%
print ('datos de la planta')
print ('temperatura: ', sensor)
print ('planta: ', planta)
# Out:
# datos de la planta
# temperatura:  60
# planta:  fa

# %%
if (temperatura >20 and temperatura <=40):
    print ('no necesita regarse aun')
elif (temperatura < 41 and temperatura <=60):
    print ('regar la planta')
elif (temperatura <61 and temperatura <=100):
    print ('se quemo la planta')
else:
    print ('es cactus')
# Out:
# se quemo la planta
