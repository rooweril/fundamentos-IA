# %% [markdown]
# ### laboratorio 3
#
# ### obketivo: un videojuego utliza un agente inteligente enemigo que debe decidir si puede iniciar un ataque contra el jugador
# **fecha** 7 de septiembre

# %% [markdown]
# #preposiciones
# P : se enncuentra dentro del rango
# Q : el nivel de vida es suficiente
# R : existe municion disponible
# T : no existe amenaza cercana
# U : no esta aturdido

# %% [markdown]
# #definicion de variables
#
# rango = True #si esta dentro del rango
# vida = True #si tiene vida suficiente
# municion = True #si tiene municion disponible
# visible = True #si es visible el jugador
# amenaza = False #no existe amenaza cercana
# aturdido = False #no esta aturdido

# %% [markdown]
# PuedeAtacar= ( rango==True and visible==True and vida==True and municion==True and amenaza==False and aturdido==False )

# %% [markdown]
# print ("el agente enemigo puede atacar", puedeatacar)
# El agente enemigo puede atacar? True

# %%
print (" == Agente Enemigo Inteligente ==")
print ("Development by fa")

rango = input (" El jugador se encuentra denntro del rango (S/N): ").lower() == "S"
visible = input ('el jugador es visible (s/n): ').lower() == 's'
vida = input ('el enemigo tiene vida (s/n): ').lower() == 's'
municion= input ('el enemigo tiene municion (s/n): ').lower =='s'
amenaza= input ('hay amenazas cerca (s/n): ').lower =='n'
aturdido= input ('el enemigo esta aturdido (s/n): ').lower=='n'

puedeatacar= (rango==True and visible==True and vida==true and municion==True and amenaza==False and aturdido==False)

print ('desicion del agente')
if puedeatacar==True :
    print ('ataca')
else:
    print ('no ataques')
# Out:
#  == Agente Enemigo Inteligente ==
# Development by fa
#  El jugador se encuentra denntro del rango (S/N):  s
# el jugador es visible (s/n):  s
# el enemigo tiene vida (s/n):  s
# el enemigo tiene municion (s/n):  s
# hay amenazas cerca (s/n):  n
# el enemigo esta aturdido (s/n):  n
# desicion del agente
# no ataques
