# %% [markdown]
# ## laboratorio 4
#
# ### preposiciones P=el servidor principal esta disponible Q=la latencia supera el limite R=la perdida de paquetes supera el limite
# ### S=el trafico de red es alto T=el servidor de respaldo no esta disponible U=el sistema de monitoreo esta activo

# %% [markdown]
# # preposiciones
# P:el servidor principal esta disponible
# Q:la latencia supera el limite
# R:la perdida de paquetes supera el limite
# S:el trafico de red es alto
# T:el servidor de respaldo no esta disponible
# U:el sistema de monitoreo esta activo

# %% [markdown]
# # definicion de variables
# servprindisp = True
# Latenciaalta = True
# perdidapaquetesalt = True
# Traficoalto = True
# Servresp = True
# monitoactivo = True

# %% [markdown]
# estadocritico= ( servprindisp==True and latenciaalta==True and perdidapaquetesalta==True and traficoalto==True and servresp==True and monitoactivo==True )

# %% [markdown]
# print ("el estado es critico", estadocritico)
# El estado es critico? True

# %%
print("== Sistema de Red ==")
print("Development by fa")

servidorPrincipal = input ("El servidor principal no está disponible? (s/n): ").lower()=="s"
latencia = input ("La latencia supera el límite establecido? (s/n): ").lower()=="s"
perdidaPaquetes = input ("La pérdida de paquetes supera el límite permitido? (s/n): ").lower()=="s"
traficoAlto = input ("El tráfico de red es anormalmente alto (s/n): ").lower()=="s"
servidorRespaldo = input ("El servidor de respaldo no está disponible? (s/n): ").lower()=="s"
monitoreo = input ("El sistema de monitoreo está activo? (s/n): ").lower()=="s"

condicionCritica= (servidorPrincipal == False and latencia == True and perdidaPaquetes == True and traficoAlto == True and servidorRespaldo == False and monitoreo == True)

print("Decisión del sistema")
if condicionCritica == True:
    print("Existe una condición crítica de servicio")
else:
    print("No existe una condición crítica de servicio")
# Out:
# == Sistema de Red ==
# Development by fa
# El servidor principal no está disponible? (s/n):  s
# La latencia supera el límite establecido? (s/n):  n
# La pérdida de paquetes supera el límite permitido? (s/n):  n
# El tráfico de red es anormalmente alto (s/n):  n
# El servidor de respaldo no está disponible? (s/n):  s
# El sistema de monitoreo está activo? (s/n):  s
# Decisión del sistema
# No existe una condición crítica de servicio
